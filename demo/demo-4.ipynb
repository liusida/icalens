# %%
# !uv run icalens fit text \
  --layers 6 \
  --token-budget 1000 \
  --max-iter 20 \
  --output /tmp/icalens-gpt-2-layer-6-1k
# Out:
# Uninstalled 1 package in 0.55ms
# Installed 1 package in 2msu13==0.8.1
# [2026-08-12 13:21:19 +08] Resolving model openai-community/gpt2 and dataset NeelNanda/pile-10k revisions...
# [2026-08-12 13:21:20 +08] Loading tokenizer and NeelNanda/pile-10k candidate tokens...
# Tokenize NeelNanda/pile-10k: 100%|█| 1000/1000 [00:02<00:00, 396.09tok/s, docum
# [2026-08-12 13:21:25 +08] Loaded 1000 candidate tokens from 1 documents.
# [2026-08-12 13:21:25 +08] Loading openai-community/gpt2@607a30d783dfa663caf39e06633721c8d4cfcd7e on CUDA...
# Loading weights: 100%|██████████████████████| 148/148 [00:00<00:00, 572.83it/s]
# [2026-08-12 13:21:26 +08] Capturing 1000 sampled activations for layers 6...
# Capture activations: 100%|██| 1000/1000 [00:00<00:00, 3268.82tok/s, document=0]
# [2026-08-12 13:21:26 +08] Fitting layer 6 from 1000 tokens with 768 components, max_iter=5, fit_batch_size=8192...
# FastICA mean: 100%|██████████████████| 1.00k/1.00k [00:00<00:00, 14.4ksample/s]
# ...

# %%
# !uv run icalens --help
# Out:
# Uninstalled 2 packages in 0.61ms
# Installed 2 packages in 0.69msom file:///home/liusida/resear
# usage: icalens COMMAND [OPTIONS]
#
# Fit, publish, and verify ICA Lens artifacts.
#
# commands:
#   fit text     Fit from a raw-text dataset
#   fit chat     Fit from a conversation dataset
#   publish      Publish a local artifact to Hugging Face
#   smoke-test   Verify installed text and chat analysis paths
#
# Run 'icalens COMMAND --help' for command-specific options.
